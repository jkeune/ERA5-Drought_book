# %% [markdown]
# # Explanation

# %% [markdown]
# Welcome to the ERA5-Drought explanation collection!
#
# Here you'll find some background information around ERA5-Drought.
#
# - [Understanding Drought (Indices)](explanations/understanding_drought.md)
